# %%
from bs4 import BeautifulSoup
import requests

# %%
url='https://coinmarketcap.com/currencies/bitcoin/'
page=requests.get(url)
print(page)
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.text,'html')
print(soup)
# Out:
# <!DOCTYPE html>
# ...

# %%
soup.find('span',"sc-c1554bc0-0 hhUhBo")
# Out:
# <span class="sc-c1554bc0-0 hhUhBo" data-role="coin-name" title="Bitcoin">Bitcoin<span class="sc-c1554bc0-0 iSUEMj coin-name-mobile"> price</span></span>

# %%
crypto=soup.find('span',"sc-c1554bc0-0 hhUhBo").text[:7]

# %%
crypto
# Out:
# 'Bitcoin'

# %%
crypto_price=soup.find('span',"sc-c1554bc0-0 RbQXx base-text").text[1:]

# %%
crypto_price
# Out:
# '64,342.39'

# %%
import pandas as pd

# %%
from datetime import datetime
dt=datetime.now()
print(dt)
# Out:
# 2026-08-19 14:19:35.068244

# %%
dt=datetime.now()
dict={'crypto_name':crypto,'price':crypto_price,'Timestamp':dt}
df=pd.DataFrame(dict,index=[0])
df
# Out:
#   crypto_name      price                  Timestamp
# 0     Bitcoin  64,342.39 2026-08-19 14:22:07.425694

# %%
df.to_csv(r'C:\Users\User\OneDrive\Desktop\PYTHON COURSE\Analyst_Builder_Python\Crypto_Web_pul\crypto_automated_pull.csv')

# %%
import os

# %%
if os.path.exists(r'C:\Users\User\OneDrive\Desktop\PYTHON COURSE\Analyst_Builder_Python\Crypto_Web_pul\crypto_automated_pull.csv'):
    df.to_csv(r'C:\Users\User\OneDrive\Desktop\PYTHON COURSE\Analyst_Builder_Python\Crypto_Web_pul\crypto_automated_pull.csv',mode='a',header=False)
else:
    df.to_csv(r'C:\Users\User\OneDrive\Desktop\PYTHON COURSE\Analyst_Builder_Python\Crypto_Web_pul\crypto_automated_pull.csv')

# %%
# Putting it all together

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from datetime import datetime
import os
import time

# %%
def automated_crypto_pull():

    url='https://coinmarketcap.com/currencies/bitcoin/'
    page=requests.get(url)
    
    soup=BeautifulSoup(page.text,'html')
    crypto=soup.find('span',"sc-c1554bc0-0 hhUhBo").text[:7]
    crypto_price=soup.find('span',"sc-c1554bc0-0 RbQXx base-text").text[1:]
    
    dt=datetime.now()
    dict={'crypto_name':crypto,'price':crypto_price,'Timestamp':dt}
    df=pd.DataFrame([dict])
    
    if os.path.exists(r'C:\Users\User\OneDrive\Desktop\PYTHON COURSE\Analyst_Builder_Python\Crypto_Web_pul\crypto_automated_pull.csv'):
        df.to_csv(r'C:\Users\User\OneDrive\Desktop\PYTHON COURSE\Analyst_Builder_Python\Crypto_Web_pul\crypto_automated_pull.csv',mode='a',header=False,index=False)
    else:
        df.to_csv(r'C:\Users\User\OneDrive\Desktop\PYTHON COURSE\Analyst_Builder_Python\Crypto_Web_pul\crypto_automated_pull.csv',index=False)
    print(df)

# %%
while True:
    automated_crypto_pull()
    time.sleep (25)
# Out:
#   crypto_name      price                  Timestamp
# 0     Bitcoin  64,447.10 2026-08-19 15:13:40.112192
#   crypto_name      price                  Timestamp
# 0     Bitcoin  64,447.10 2026-08-19 15:14:05.383178
#   crypto_name      price                  Timestamp
# 0     Bitcoin  64,447.10 2026-08-19 15:14:30.632511
#   crypto_name      price                  Timestamp
# 0     Bitcoin  64,447.10 2026-08-19 15:14:55.914385
#   crypto_name      price                  Timestamp
# 0     Bitcoin  64,458.25 2026-08-19 15:15:21.183429
#   crypto_name      price                  Timestamp
# 0     Bitcoin  64,458.25 2026-08-19 15:15:46.467710
#   crypto_name      price                  Timestamp
# 0     Bitcoin  64,447.10 2026-08-19 15:16:11.801461
#   crypto_name      price                  Timestamp
# 0     Bitcoin  64,447.10 2026-08-19 15:16:37.046192
#   crypto_name      price                  Timestamp
# 0     Bitcoin  64,447.10 2026-08-19 15:17:02.308049
# ...
